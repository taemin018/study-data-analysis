# %% [markdown]
# ### 판다스 (Pandas)
# - 데이터 처리 라이브러리 중 가장 인기있는 라이브러리이다.
# - 2차원 데이터(테이블, 엑셀, CSV 등)를 효율적으로 가공 및 처리할 수 있다.

# %% [markdown]
# #### 판다스 구성 요소
# - DataFrame: 행과 열로 구성된 2차원 Dataset을 의미한다.
# - Series: 1개의 열로만 구성된 열벡터 Dataset을 의미한다.
# - Index: DataFrame과 Series에서 중복없는 행 번호를 의미한다.

# %%
import pandas as pd

pd.__version__
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 import pandas as pd
#       3 pd.__version__
#
# ModuleNotFoundError: No module named 'pandas'

# %%
# Out:
# gettext-0.21.0       | 3.1 MB    | ###################1                  |  52%
#
#
# libmambapy-2.3.2     | 572 KB    | #####################7                |  59%
#
# qt-main-5.15.2       | 38.5 MB   | 6                                     |   2%
#
#
#
#
#
#
#
#
#
#
# lcms2-2.16           | 238 KB    | ##4                                   |   7%
#
#
#
#
#
#
#
#
# libllvm14-14.0.6     | 22.8 MB   | 3                                     |   1%
#
#
#
# gettext-0.21.0       | 3.1 MB    | ###################7                  |  53%
#
# qt-main-5.15.2       | 38.5 MB   | 6                                     |   2%
#
#
# libmambapy-2.3.2     | 572 KB    | #######################8              |  64%
#
#
#
#
#
#
#
#
#
#
# lcms2-2.16           | 238 KB    | #######4                              |  20%
#
#
#
#
#
#
#
#
# libllvm14-14.0.6     | 22.8 MB   | 4                                     |   1%
#
#
#
#
#
#
#
#
#
#
# lcms2-2.16           | 238 KB    | ##############9                       |  40%
#
# qt-main-5.15.2       | 38.5 MB   | 7                                     |   2%
#
#
#
# gettext-0.21.0       | 3.1 MB    | ####################2                 |  55%
#
#
# libmambapy-2.3.2     | 572 KB    | #########################8            |  70%
#
#
#
#
#
#
#
#
# libllvm14-14.0.6     | 22.8 MB   | 4                                     |   1%
#
#
#
#
#
#
#
#
#
#
# lcms2-2.16           | 238 KB    | ###################9                  |  54%
#
#
#
# gettext-0.21.0       | 3.1 MB    | ####################6                 |  56%
#
# qt-main-5.15.2       | 38.5 MB   | 7                                     |   2%
#
#
# libmambapy-2.3.2     | 572 KB    | ###########################9          |  76%
#
#
#
#
#
#
#
#
# libllvm14-14.0.6     | 22.8 MB   | 5                                     |   1%
#
#
#
# gettext-0.21.0       | 3.1 MB    | #####################                 |  57%
#
#
#
#
#
#
#
#
#
#
# lcms2-2.16           | 238 KB    | ###########################4          |  74%
#
# qt-main-5.15.2       | 38.5 MB   | 7                                     |   2%
#
#
#
#
#
#
#
#
# libllvm14-14.0.6     | 22.8 MB   | 5                                     |   2%
#
#
# libmambapy-2.3.2     | 572 KB    | ##############################        |  81%
#
#
#
# gettext-0.21.0       | 3.1 MB    | #####################4                |  58%
#
# qt-main-5.15.2       | 38.5 MB   | 8                                     |   2%
#
#
#
#
#
#
#
#
#
#
# lcms2-2.16           | 238 KB    | ##################################8   |  94%
#
#
#
#
#
#
#
#
# libllvm14-14.0.6     | 22.8 MB   | 6                                     |   2%
#
#
#
#
#
#
#
#
#
#
# lcms2-2.16           | 238 KB    | ##################################### | 100%
#
#
#
# gettext-0.21.0       | 3.1 MB    | #####################7                |  59%
#
#
# libmambapy-2.3.2     | 572 KB    | ################################      |  87%
#
# qt-main-5.15.2       | 38.5 MB   | 8                                     |   2%
#
#
#
#
#
#
#
#
# libllvm14-14.0.6     | 22.8 MB   | 7                                     |   2%
#
#
#
# gettext-0.21.0       | 3.1 MB    | ######################3               |  60%
#
#
#
#
#
#
#
#
#
#
#
# patch-2.8            | 125 KB    | ####7                                 |  13%
#
# qt-main-5.15.2       | 38.5 MB   | 9                                     |   2%
#
#
# libmambapy-2.3.2     | 572 KB    | ##################################1   |  92%
#
#
#
#
#
#
#
#
#
#
#
# patch-2.8            | 125 KB    | ##################9                   |  51%
#
#
#
#
#
#
#
#
# libllvm14-14.0.6     | 22.8 MB   | 7                                     |   2%
#
#
#
# gettext-0.21.0       | 3.1 MB    | ######################7               |  61%
#
# qt-main-5.15.2       | 38.5 MB   | 9                                     |   3%
#
#
#
#
#
#
#
#
# libllvm14-14.0.6     | 22.8 MB   | 8                                     |   2%
#
#
#
#
#
#
#
#
#
#
#
# patch-2.8            | 125 KB    | ############################4         |  77%
#
#
# libmambapy-2.3.2     | 572 KB    | ####################################2 |  98%
#
#
#
# gettext-0.21.0       | 3.1 MB    | #######################               |  62%
#
#
#
#
#
#
#
#
#
#
#
# patch-2.8            | 125 KB    | ##################################### | 100%
#
#
# libmambapy-2.3.2     | 572 KB    | ##################################### | 100%
#
# qt-main-5.15.2       | 38.5 MB   | 9                                     |   3%
#
#
#
#
#
#
#
#
# libllvm14-14.0.6     | 22.8 MB   | 8                                     |   2%
#
#
#
# gettext-0.21.0       | 3.1 MB    | #######################6              |  64%
#
#
#
#
#
#
#
#
#
#
#
#
#
# shellingham-1.5.4    | 23 KB     | #########################8            |  70%
#
#
#
#
#
#
#
#
# libllvm14-14.0.6     | 22.8 MB   | 9                                     |   3%
#
# qt-main-5.15.2       | 38.5 MB   | #                                     |   3%
#
#
#
#
#
#
#
#
#
#
#
#
#
# shellingham-1.5.4    | 23 KB     | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
# ruamel.yaml.clib-0.2 | 112 KB    | #####3                                |  14%
#
#
#
# gettext-0.21.0       | 3.1 MB    | ########################              |  65%
#
#
#
#
#
#
#
#
# libllvm14-14.0.6     | 22.8 MB   | #                                     |   3%
#
# qt-main-5.15.2       | 38.5 MB   | #                                     |   3%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# soupsieve-2.5        | 96 KB     | ######1                               |  17%
#
#
#
# gettext-0.21.0       | 3.1 MB    | ########################5             |  66%
#
#
#
#
#
#
#
#
#
#
#
#
# ruamel.yaml.clib-0.2 | 112 KB    | ###############9                      |  43%
#
#
#
#
#
#
#
#
# libllvm14-14.0.6     | 22.8 MB   | #                                     |   3%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# soupsieve-2.5        | 96 KB     | ########################6             |  67%
#
# qt-main-5.15.2       | 38.5 MB   | #                                     |   3%
#
#
#
# gettext-0.21.0       | 3.1 MB    | ########################9             |  67%
#
#
#
#
#
#
#
#
#
#
#
#
# ruamel.yaml.clib-0.2 | 112 KB    | ##########################5           |  72%
#
#
#
#
#
#
#
#
# libllvm14-14.0.6     | 22.8 MB   | #1                                    |   3%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# soupsieve-2.5        | 96 KB     | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# soupsieve-2.5        | 96 KB     | ##################################### | 100%
#
# qt-main-5.15.2       | 38.5 MB   | #1                                    |   3%
#
#
#
# gettext-0.21.0       | 3.1 MB    | #########################5            |  69%
#
#
#
#
#
#
#
#
#
#
#
#
# ruamel.yaml.clib-0.2 | 112 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
# libllvm14-14.0.6     | 22.8 MB   | #1                                    |   3%
#
#
#
#
#
#
#
#
#
#
#
#
# ruamel.yaml.clib-0.2 | 112 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# backports-1.1        | 6 KB      | ##################################### | 100%
# backports-1.1        | 6 KB      | ##################################### | 100%
#
# qt-main-5.15.2       | 38.5 MB   | #1                                    |   3%
#
#
#
# gettext-0.21.0       | 3.1 MB    | ##########################1           |  71%
#
#
#
#
#
#
#
#
# libllvm14-14.0.6     | 22.8 MB   | #2                                    |   3%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# freetype-2.13.3      | 626 KB    | 9                                     |   3%
#
# qt-main-5.15.2       | 38.5 MB   | #1                                    |   3%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# freetype-2.13.3      | 626 KB    | #8                                    |   5%
#
#
#
# gettext-0.21.0       | 3.1 MB    | ##########################6           |  72%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libpng-1.6.50        | 215 KB    | ##7                                   |   7%
#
# qt-main-5.15.2       | 38.5 MB   | #2                                    |   3%
#
#
#
#
#
#
#
#
# libllvm14-14.0.6     | 22.8 MB   | #3                                    |   4%
#
#
#
# gettext-0.21.0       | 3.1 MB    | ###########################           |  73%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libpng-1.6.50        | 215 KB    | ########2                             |  22%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# freetype-2.13.3      | 626 KB    | ####7                                 |  13%
#
# qt-main-5.15.2       | 38.5 MB   | #2                                    |   3%
#
#
#
#
#
#
#
#
# libllvm14-14.0.6     | 22.8 MB   | #4                                    |   4%
#
#
#
# gettext-0.21.0       | 3.1 MB    | ###########################4          |  74%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# freetype-2.13.3      | 626 KB    | ######6                               |  18%
#
#
#
#
#
#
#
#
# libllvm14-14.0.6     | 22.8 MB   | #4                                    |   4%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libpng-1.6.50        | 215 KB    | #############7                        |  37%
#
# qt-main-5.15.2       | 38.5 MB   | #2                                    |   3%
#
#
#
# gettext-0.21.0       | 3.1 MB    | ###########################7          |  75%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# freetype-2.13.3      | 626 KB    | ########5                             |  23%
#
#
#
# gettext-0.21.0       | 3.1 MB    | ############################1         |  76%
#
# qt-main-5.15.2       | 38.5 MB   | #3                                    |   4%
#
#
#
#
#
#
#
#
# libllvm14-14.0.6     | 22.8 MB   | #5                                    |   4%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libpng-1.6.50        | 215 KB    | ###################2                  |  52%
#
# qt-main-5.15.2       | 38.5 MB   | #3                                    |   4%
#
#
#
# gettext-0.21.0       | 3.1 MB    | ############################5         |  77%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# freetype-2.13.3      | 626 KB    | ###########3                          |  31%
#
#
#
#
#
#
#
#
# libllvm14-14.0.6     | 22.8 MB   | #6                                    |   4%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libpng-1.6.50        | 215 KB    | ########################7             |  67%
#
# qt-main-5.15.2       | 38.5 MB   | #3                                    |   4%
#
#
#
# gettext-0.21.0       | 3.1 MB    | ############################9         |  78%
#
#
#
#
#
#
#
#
# libllvm14-14.0.6     | 22.8 MB   | #6                                    |   5%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# freetype-2.13.3      | 626 KB    | ##############1                       |  38%
#
# qt-main-5.15.2       | 38.5 MB   | #4                                    |   4%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libpng-1.6.50        | 215 KB    | ##############################2       |  82%
#
#
#
# gettext-0.21.0       | 3.1 MB    | #############################2        |  79%
#
#
#
#
#
#
#
#
# libllvm14-14.0.6     | 22.8 MB   | #7                                    |   5%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# freetype-2.13.3      | 626 KB    | ################                      |  43%
#
#
#
# gettext-0.21.0       | 3.1 MB    | #############################6        |  80%
#
# qt-main-5.15.2       | 38.5 MB   | #4                                    |   4%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libpng-1.6.50        | 215 KB    | ###################################8  |  97%
#
#
#
#
#
#
#
#
# libllvm14-14.0.6     | 22.8 MB   | #7                                    |   5%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libpng-1.6.50        | 215 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# freetype-2.13.3      | 626 KB    | ##################9                   |  51%
#
#
#
# gettext-0.21.0       | 3.1 MB    | ##############################        |  81%
#
# qt-main-5.15.2       | 38.5 MB   | #4                                    |   4%
#
#
#
#
#
#
#
#
# libllvm14-14.0.6     | 22.8 MB   | #8                                    |   5%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# freetype-2.13.3      | 626 KB    | ####################8                 |  56%
#
#
#
# gettext-0.21.0       | 3.1 MB    | ##############################4       |  82%
#
# qt-main-5.15.2       | 38.5 MB   | #5                                    |   4%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# cpp-expected-1.1.0   | 131 KB    | ####5                                 |  12%
#
#
#
#
#
#
#
#
# libllvm14-14.0.6     | 22.8 MB   | #8                                    |   5%
#
#
#
# gettext-0.21.0       | 3.1 MB    | ##############################7       |  83%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# freetype-2.13.3      | 626 KB    | #######################6              |  64%
#
# qt-main-5.15.2       | 38.5 MB   | #5                                    |   4%
#
#
#
#
#
#
#
#
# libllvm14-14.0.6     | 22.8 MB   | #9                                    |   5%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# cpp-expected-1.1.0   | 131 KB    | #############5                        |  37%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# freetype-2.13.3      | 626 KB    | #########################5            |  69%
#
#
#
# gettext-0.21.0       | 3.1 MB    | ###############################1      |  84%
#
# qt-main-5.15.2       | 38.5 MB   | #5                                    |   4%
#
#
#
# gettext-0.21.0       | 3.1 MB    | ###############################5      |  85%
#
#
#
#
#
#
#
#
# libllvm14-14.0.6     | 22.8 MB   | ##                                    |   5%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# freetype-2.13.3      | 626 KB    | ###########################4          |  74%
#
# qt-main-5.15.2       | 38.5 MB   | #6                                    |   4%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# cpp-expected-1.1.0   | 131 KB    | ######################5               |  61%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# freetype-2.13.3      | 626 KB    | ##############################2       |  82%
#
# qt-main-5.15.2       | 38.5 MB   | #6                                    |   4%
# gettext-0.21.0       | 3.1 MB    | ###############################9      |  86%
#
#
#
#
#
#
#
#
# libllvm14-14.0.6     | 22.8 MB   | ##                                    |   6%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# cpp-expected-1.1.0   | 131 KB    | ###############################6      |  86%
#
#
#
# gettext-0.21.0       | 3.1 MB    | ################################2     |  87%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# freetype-2.13.3      | 626 KB    | ################################1     |  87%
#
# qt-main-5.15.2       | 38.5 MB   | #6                                    |   5%
#
#
#
#
#
#
#
#
# libllvm14-14.0.6     | 22.8 MB   | ##1                                   |   6%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# cpp-expected-1.1.0   | 131 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# cpp-expected-1.1.0   | 131 KB    | ##################################### | 100%
#
#
#
# gettext-0.21.0       | 3.1 MB    | ################################6     |  88%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# freetype-2.13.3      | 626 KB    | ##################################9   |  95%
#
#
#
#
#
#
#
#
# libllvm14-14.0.6     | 22.8 MB   | ##1                                   |   6%
#
# qt-main-5.15.2       | 38.5 MB   | #7                                    |   5%
#
#
#
# gettext-0.21.0       | 3.1 MB    | #################################     |  89%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# freetype-2.13.3      | 626 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# freetype-2.13.3      | 626 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# lz4-c-1.9.4          | 157 KB    | ###7                                  |  10%
#
#
#
#
#
#
#
#
# libllvm14-14.0.6     | 22.8 MB   | ##2                                   |   6%
#
# qt-main-5.15.2       | 38.5 MB   | #7                                    |   5%
#
#
#
# gettext-0.21.0       | 3.1 MB    | #################################6    |  91%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# lz4-c-1.9.4          | 157 KB    | ###########3                          |  31%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# jaraco.classes-3.4.0 | 20 KB     | #############################         |  79%
#
#
#
#
#
#
#
#
# libllvm14-14.0.6     | 22.8 MB   | ##3                                   |   6%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# jaraco.classes-3.4.0 | 20 KB     | ##################################### | 100%
#
# qt-main-5.15.2       | 38.5 MB   | #8                                    |   5%
#
#
#
# gettext-0.21.0       | 3.1 MB    | #################################9    |  92%
#
#
#
#
#
#
#
#
# libllvm14-14.0.6     | 22.8 MB   | ##3                                   |   6%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# lz4-c-1.9.4          | 157 KB    | ##################9                   |  51%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pydantic-core-2.41.4 | 1.7 MB    | 3                                     |   1%
#
#
#
# gettext-0.21.0       | 3.1 MB    | ##################################3   |  93%
#
# qt-main-5.15.2       | 38.5 MB   | #8                                    |   5%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pydantic-core-2.41.4 | 1.7 MB    | 6                                     |   2%
#
#
#
#
#
#
#
#
# libllvm14-14.0.6     | 22.8 MB   | ##4                                   |   7%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# lz4-c-1.9.4          | 157 KB    | ##########################4           |  72%
#
#
#
# gettext-0.21.0       | 3.1 MB    | ##################################7   |  94%
#
# qt-main-5.15.2       | 38.5 MB   | #9                                    |   5%
#
#
#
#
#
#
#
#
# libllvm14-14.0.6     | 22.8 MB   | ##4                                   |   7%
#
#
#
# gettext-0.21.0       | 3.1 MB    | ###################################1  |  95%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pydantic-core-2.41.4 | 1.7 MB    | #7                                    |   5%
#
# qt-main-5.15.2       | 38.5 MB   | #9                                    |   5%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# lz4-c-1.9.4          | 157 KB    | ##################################    |  92%
#
#
#
#
#
#
#
#
# libllvm14-14.0.6     | 22.8 MB   | ##5                                   |   7%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# lz4-c-1.9.4          | 157 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pydantic-core-2.41.4 | 1.7 MB    | ##4                                   |   7%
#
#
#
# gettext-0.21.0       | 3.1 MB    | ###################################4  |  96%
#
# qt-main-5.15.2       | 38.5 MB   | #9                                    |   5%
#
#
#
#
#
#
#
#
# libllvm14-14.0.6     | 22.8 MB   | ##5                                   |   7%
#
#
#
# gettext-0.21.0       | 3.1 MB    | ###################################8  |  97%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pydantic-core-2.41.4 | 1.7 MB    | ###4                                  |   9%
#
#
#
#
#
#
#
#
# libllvm14-14.0.6     | 22.8 MB   | ##6                                   |   7%
#
# qt-main-5.15.2       | 38.5 MB   | ##                                    |   5%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
#
#
# gettext-0.21.0       | 3.1 MB    | ####################################4 |  98%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pydantic-core-2.41.4 | 1.7 MB    | ####1                                 |  11%
#
#
#
#
#
#
#
#
# libllvm14-14.0.6     | 22.8 MB   | ##6                                   |   7%
#
# qt-main-5.15.2       | 38.5 MB   | ##                                    |   6%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pydantic-core-2.41.4 | 1.7 MB    | ####8                                 |  13%
#
#
#
# gettext-0.21.0       | 3.1 MB    | ####################################9 | 100%
#
#
#
#
#
#
#
#
# libllvm14-14.0.6     | 22.8 MB   | ##7                                   |   7%
#
# qt-main-5.15.2       | 38.5 MB   | ##1                                   |   6%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
#
#
# gettext-0.21.0       | 3.1 MB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pydantic-core-2.41.4 | 1.7 MB    | #####9                                |  16%
#
# qt-main-5.15.2       | 38.5 MB   | ##1                                   |   6%
#
#
#
#
#
#
#
#
# libllvm14-14.0.6     | 22.8 MB   | ##7                                   |   8%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pydantic-core-2.41.4 | 1.7 MB    | ######6                               |  18%
# libllvm14-14.0.6     | 22.8 MB   | ##8                                   |   8%
#
# qt-main-5.15.2       | 38.5 MB   | ##1                                   |   6%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pydantic-core-2.41.4 | 1.7 MB    | #######3                              |  20%
#
#
#
#
#
#
#
#
# libllvm14-14.0.6     | 22.8 MB   | ##8                                   |   8%
#
# qt-main-5.15.2       | 38.5 MB   | ##2                                   |   6%
#
#
#
#
#
#
#
#
# libllvm14-14.0.6     | 22.8 MB   | ##9                                   |   8%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pydantic-core-2.41.4 | 1.7 MB    | ########                              |  22%
#
# qt-main-5.15.2       | 38.5 MB   | ##2                                   |   6%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pydantic-core-2.41.4 | 1.7 MB    | ########6                             |  24%
#
#
#
#
#
#
#
#
# libllvm14-14.0.6     | 22.8 MB   | ###                                   |   8%
#
# qt-main-5.15.2       | 38.5 MB   | ##2                                   |   6%
#
#
#
#
#
#
#
#
# libllvm14-14.0.6     | 22.8 MB   | ###                                   |   8%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pydantic-core-2.41.4 | 1.7 MB    | #########3                            |  25%
#
# qt-main-5.15.2       | 38.5 MB   | ##3                                   |   6%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pydantic-core-2.41.4 | 1.7 MB    | ##########                            |  27%
#
#
#
#
#
#
#
#
# libllvm14-14.0.6     | 22.8 MB   | ###1                                  |   8%
#
# qt-main-5.15.2       | 38.5 MB   | ##3                                   |   6%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pydantic-core-2.41.4 | 1.7 MB    | ##########7                           |  29%
#
#
#
#
#
#
#
#
# libllvm14-14.0.6     | 22.8 MB   | ###1                                  |   9%
#
# qt-main-5.15.2       | 38.5 MB   | ##3                                   |   6%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pydantic-core-2.41.4 | 1.7 MB    | ###########4                          |  31%
#
# qt-main-5.15.2       | 38.5 MB   | ##4                                   |   7%
#
#
#
#
#
#
#
#
# libllvm14-14.0.6     | 22.8 MB   | ###2                                  |   9%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pydantic-core-2.41.4 | 1.7 MB    | ############1                         |  33%
#
#
#
#
#
#
#
#
# libllvm14-14.0.6     | 22.8 MB   | ###2                                  |   9%
#
# qt-main-5.15.2       | 38.5 MB   | ##4                                   |   7%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pydantic-core-2.41.4 | 1.7 MB    | ############8                         |  35%
#
#
#
#
#
#
#
#
# libllvm14-14.0.6     | 22.8 MB   | ###3                                  |   9%
#
# qt-main-5.15.2       | 38.5 MB   | ##4                                   |   7%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pydantic-core-2.41.4 | 1.7 MB    | #############5                        |  37%
#
#
#
#
#
#
#
#
# libllvm14-14.0.6     | 22.8 MB   | ###3                                  |   9%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pydantic-core-2.41.4 | 1.7 MB    | ##############2                       |  39%
#
# qt-main-5.15.2       | 38.5 MB   | ##5                                   |   7%
#
#
#
#
#
#
#
#
# libllvm14-14.0.6     | 22.8 MB   | ###4                                  |   9%
#
# qt-main-5.15.2       | 38.5 MB   | ##5                                   |   7%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pydantic-core-2.41.4 | 1.7 MB    | ##############9                       |  40%
#
#
#
#
#
#
#
#
# libllvm14-14.0.6     | 22.8 MB   | ###4                                  |   9%
#
# qt-main-5.15.2       | 38.5 MB   | ##5                                   |   7%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pydantic-core-2.41.4 | 1.7 MB    | ################                      |  43%
#
#
#
#
#
#
#
#
# libllvm14-14.0.6     | 22.8 MB   | ###5                                  |  10%
#
# qt-main-5.15.2       | 38.5 MB   | ##6                                   |   7%
#
#
#
#
#
#
#
#
# libllvm14-14.0.6     | 22.8 MB   | ###5                                  |  10%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pydantic-core-2.41.4 | 1.7 MB    | #################                     |  46%
#
# qt-main-5.15.2       | 38.5 MB   | ##6                                   |   7%
#
#
#
#
#
#
#
#
# libllvm14-14.0.6     | 22.8 MB   | ###6                                  |  10%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pydantic-core-2.41.4 | 1.7 MB    | ##################                    |  49%
#
# qt-main-5.15.2       | 38.5 MB   | ##6                                   |   7%
#
#
#
#
#
#
#
#
# libllvm14-14.0.6     | 22.8 MB   | ###7                                  |  10%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pydantic-core-2.41.4 | 1.7 MB    | ###################1                  |  52%
#
# qt-main-5.15.2       | 38.5 MB   | ##7                                   |   7%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pydantic-core-2.41.4 | 1.7 MB    | ###################8                  |  54%
#
#
#
#
#
#
#
#
# libllvm14-14.0.6     | 22.8 MB   | ###7                                  |  10%
#
# qt-main-5.15.2       | 38.5 MB   | ##7                                   |   7%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pydantic-core-2.41.4 | 1.7 MB    | ####################5                 |  55%
#
#
#
#
#
#
#
#
# libllvm14-14.0.6     | 22.8 MB   | ###8                                  |  10%
#
# qt-main-5.15.2       | 38.5 MB   | ##7                                   |   8%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pydantic-core-2.41.4 | 1.7 MB    | #####################2                |  57%
#
#
#
#
#
#
#
#
# libllvm14-14.0.6     | 22.8 MB   | ###8                                  |  10%
#
# qt-main-5.15.2       | 38.5 MB   | ##8                                   |   8%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pydantic-core-2.41.4 | 1.7 MB    | #####################9                |  59%
#
#
#
#
#
#
#
#
# libllvm14-14.0.6     | 22.8 MB   | ###9                                  |  11%
#
# qt-main-5.15.2       | 38.5 MB   | ##8                                   |   8%
#
#
#
#
#
#
#
#
# libllvm14-14.0.6     | 22.8 MB   | ###9                                  |  11%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pydantic-core-2.41.4 | 1.7 MB    | ######################9               |  62%
#
# qt-main-5.15.2       | 38.5 MB   | ##8                                   |   8%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pydantic-core-2.41.4 | 1.7 MB    | #######################6              |  64%
# libllvm14-14.0.6     | 22.8 MB   | ####                                  |  11%
#
# qt-main-5.15.2       | 38.5 MB   | ##9                                   |   8%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pydantic-core-2.41.4 | 1.7 MB    | ########################3             |  66%
#
#
#
#
#
#
#
#
# libllvm14-14.0.6     | 22.8 MB   | ####1                                 |  11%
#
# qt-main-5.15.2       | 38.5 MB   | ##9                                   |   8%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pydantic-core-2.41.4 | 1.7 MB    | #########################4            |  69%
#
#
#
#
#
#
#
#
# libllvm14-14.0.6     | 22.8 MB   | ####2                                 |  11%
#
# qt-main-5.15.2       | 38.5 MB   | ##9                                   |   8%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pydantic-core-2.41.4 | 1.7 MB    | ##########################            |  71%
#
# qt-main-5.15.2       | 38.5 MB   | ###                                   |   8%
#
#
#
#
#
#
#
#
# libllvm14-14.0.6     | 22.8 MB   | ####2                                 |  11%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pydantic-core-2.41.4 | 1.7 MB    | ##########################7           |  72%
#
# qt-main-5.15.2       | 38.5 MB   | ###                                   |   8%
#
#
#
#
#
#
#
#
# libllvm14-14.0.6     | 22.8 MB   | ####3                                 |  12%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pydantic-core-2.41.4 | 1.7 MB    | ###########################4          |  74%
#
# qt-main-5.15.2       | 38.5 MB   | ###                                   |   8%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pydantic-core-2.41.4 | 1.7 MB    | ############################1         |  76%
#
#
#
#
#
#
#
#
# libllvm14-14.0.6     | 22.8 MB   | ####3                                 |  12%
#
# qt-main-5.15.2       | 38.5 MB   | ###                                   |   8%
#
#
#
#
#
#
#
#
# libllvm14-14.0.6     | 22.8 MB   | ####4                                 |  12%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pydantic-core-2.41.4 | 1.7 MB    | #############################2        |  79%
#
# qt-main-5.15.2       | 38.5 MB   | ###1                                  |   8%
#
#
#
#
#
#
#
#
# libllvm14-14.0.6     | 22.8 MB   | ####4                                 |  12%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pydantic-core-2.41.4 | 1.7 MB    | #############################9        |  81%
#
# qt-main-5.15.2       | 38.5 MB   | ###1                                  |   9%
#
#
#
#
#
#
#
#
# libllvm14-14.0.6     | 22.8 MB   | ####5                                 |  12%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pydantic-core-2.41.4 | 1.7 MB    | ##############################9       |  84%
#
# qt-main-5.15.2       | 38.5 MB   | ###1                                  |   9%
#
#
#
#
#
#
#
#
# libllvm14-14.0.6     | 22.8 MB   | ####6                                 |  12%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pydantic-core-2.41.4 | 1.7 MB    | ###############################6      |  86%
#
# qt-main-5.15.2       | 38.5 MB   | ###2                                  |   9%
#
#
#
#
#
#
#
#
# libllvm14-14.0.6     | 22.8 MB   | ####6                                 |  13%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pydantic-core-2.41.4 | 1.7 MB    | ################################7     |  88%
#
# qt-main-5.15.2       | 38.5 MB   | ###2                                  |   9%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pydantic-core-2.41.4 | 1.7 MB    | #################################4    |  90%
#
#
#
#
#
#
#
#
# libllvm14-14.0.6     | 22.8 MB   | ####7                                 |  13%
#
# qt-main-5.15.2       | 38.5 MB   | ###2                                  |   9%
#
#
#
#
#
#
#
#
# libllvm14-14.0.6     | 22.8 MB   | ####8                                 |  13%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pydantic-core-2.41.4 | 1.7 MB    | ##################################    |  92%
#
# qt-main-5.15.2       | 38.5 MB   | ###3                                  |   9%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pydantic-core-2.41.4 | 1.7 MB    | ###################################1  |  95%
#
#
#
#
#
#
#
#
# libllvm14-14.0.6     | 22.8 MB   | ####8                                 |  13%
#
# qt-main-5.15.2       | 38.5 MB   | ###3                                  |   9%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pydantic-core-2.41.4 | 1.7 MB    | ###################################8  |  97%
#
#
#
#
#
#
#
#
# libllvm14-14.0.6     | 22.8 MB   | ####9                                 |  13%
#
# qt-main-5.15.2       | 38.5 MB   | ###3                                  |   9%
#
#
#
#
#
#
#
#
# libllvm14-14.0.6     | 22.8 MB   | #####                                 |  14%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pydantic-core-2.41.4 | 1.7 MB    | ####################################8 | 100%
#
# qt-main-5.15.2       | 38.5 MB   | ###4                                  |   9%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pydantic-core-2.41.4 | 1.7 MB    | ##################################### | 100%
#
#
#
#
#
#
#
#
# libllvm14-14.0.6     | 22.8 MB   | #####                                 |  14%
#
# qt-main-5.15.2       | 38.5 MB   | ###4                                  |   9%
#
#
#
#
#
#
#
#
# libllvm14-14.0.6     | 22.8 MB   | #####1                                |  14%
#
# qt-main-5.15.2       | 38.5 MB   | ###4                                  |   9%
#
#
#
#
#
#
#
#
# libllvm14-14.0.6     | 22.8 MB   | #####2                                |  14%
#
# qt-main-5.15.2       | 38.5 MB   | ###5                                  |  10%
#
#
#
#
#
#
#
#
# libllvm14-14.0.6     | 22.8 MB   | #####3                                |  14%
#
# qt-main-5.15.2       | 38.5 MB   | ###5                                  |  10%
#
#
#
#
#
#
#
#
# libllvm14-14.0.6     | 22.8 MB   | #####3                                |  15%
#
# qt-main-5.15.2       | 38.5 MB   | ###5                                  |  10%
#
#
#
#
#
#
#
#
# libllvm14-14.0.6     | 22.8 MB   | #####4                                |  15%
#
# qt-main-5.15.2       | 38.5 MB   | ###6                                  |  10%
#
# qt-main-5.15.2       | 38.5 MB   | ###6                                  |  10%
#
#
#
#
#
#
#
#
# libllvm14-14.0.6     | 22.8 MB   | #####5                                |  15%
#
# qt-main-5.15.2       | 38.5 MB   | ###6                                  |  10%
#
#
#
#
#
#
#
#
# libllvm14-14.0.6     | 22.8 MB   | #####6                                |  15%
#
#
#
#
#
#
#
#
# libllvm14-14.0.6     | 22.8 MB   | #####6                                |  15%
#
# qt-main-5.15.2       | 38.5 MB   | ###7                                  |  10%
#
#
#
#
#
#
#
#
# libllvm14-14.0.6     | 22.8 MB   | #####7                                |  16%
# qt-main-5.15.2       | 38.5 MB   | ###7                                  |  10%
#
# qt-main-5.15.2       | 38.5 MB   | ###8                                  |  10%
#
#
#
#
#
#
#
#
# libllvm14-14.0.6     | 22.8 MB   | #####8                                |  16%
#
# qt-main-5.15.2       | 38.5 MB   | ###8                                  |  10%
#
# qt-main-5.15.2       | 38.5 MB   | ###8                                  |  10%
#
#
#
#
#
#
#
#
# libllvm14-14.0.6     | 22.8 MB   | #####9                                |  16%
#
# qt-main-5.15.2       | 38.5 MB   | ###8                                  |  11%
#
#
#
#
#
#
#
#
# libllvm14-14.0.6     | 22.8 MB   | #####9                                |  16%
#
# qt-main-5.15.2       | 38.5 MB   | ###9                                  |  11%
#
#
#
#
#
#
#
#
# libllvm14-14.0.6     | 22.8 MB   | ######                                |  16%
#
# qt-main-5.15.2       | 38.5 MB   | ###9                                  |  11%
#
#
#
#
#
#
#
#
# libllvm14-14.0.6     | 22.8 MB   | ######1                               |  16%
#
# qt-main-5.15.2       | 38.5 MB   | ###9                                  |  11%
#
#
#
#
#
#
#
#
# libllvm14-14.0.6     | 22.8 MB   | ######1                               |  17%
#
# qt-main-5.15.2       | 38.5 MB   | ####                                  |  11%
#
#
#
#
#
#
#
#
# libllvm14-14.0.6     | 22.8 MB   | ######2                               |  17%
#
# qt-main-5.15.2       | 38.5 MB   | ####                                  |  11%
#
#
#
#
#
#
#
#
# libllvm14-14.0.6     | 22.8 MB   | ######2                               |  17%
#
# qt-main-5.15.2       | 38.5 MB   | ####                                  |  11%
#
#
#
#
#
#
#
#
# libllvm14-14.0.6     | 22.8 MB   | ######3                               |  17%
#
# qt-main-5.15.2       | 38.5 MB   | ####1                                 |  11%
#
#
#
#
#
#
#
#
# libllvm14-14.0.6     | 22.8 MB   | ######3                               |  17%
#
# qt-main-5.15.2       | 38.5 MB   | ####1                                 |  11%
#
#
#
#
#
#
#
#
# libllvm14-14.0.6     | 22.8 MB   | ######4                               |  17%
#
# qt-main-5.15.2       | 38.5 MB   | ####1                                 |  11%
#
#
#
#
#
#
#
#
# libllvm14-14.0.6     | 22.8 MB   | ######4                               |  18%
#
# qt-main-5.15.2       | 38.5 MB   | ####2                                 |  11%
#
#
#
#
#
#
#
#
# libllvm14-14.0.6     | 22.8 MB   | ######5                               |  18%
#
# qt-main-5.15.2       | 38.5 MB   | ####2                                 |  11%
#
#
#
#
#
#
#
#
# libllvm14-14.0.6     | 22.8 MB   | ######6                               |  18%
#
# qt-main-5.15.2       | 38.5 MB   | ####2                                 |  12%
#
#
#
#
#
#
#
#
# libllvm14-14.0.6     | 22.8 MB   | ######6                               |  18%
#
# qt-main-5.15.2       | 38.5 MB   | ####3                                 |  12%
#
#
#
#
#
#
#
#
# libllvm14-14.0.6     | 22.8 MB   | ######7                               |  18%
#
# qt-main-5.15.2       | 38.5 MB   | ####3                                 |  12%
#
#
#
#
#
#
#
#
# libllvm14-14.0.6     | 22.8 MB   | ######8                               |  18%
#
#
#
#
#
#
#
#
# libllvm14-14.0.6     | 22.8 MB   | ######8                               |  19%
#
# qt-main-5.15.2       | 38.5 MB   | ####4                                 |  12%
#
#
#
#
#
#
#
#
# libllvm14-14.0.6     | 22.8 MB   | ######9                               |  19%
#
# qt-main-5.15.2       | 38.5 MB   | ####4                                 |  12%
#
#
#
#
#
#
#
#
# libllvm14-14.0.6     | 22.8 MB   | ######9                               |  19%
#
# qt-main-5.15.2       | 38.5 MB   | ####4                                 |  12%
#
#
#
#
#
#
#
#
# libllvm14-14.0.6     | 22.8 MB   | #######                               |  19%
#
# qt-main-5.15.2       | 38.5 MB   | ####5                                 |  12%
#
# qt-main-5.15.2       | 38.5 MB   | ####5                                 |  12%
#
#
#
#
#
#
#
#
# libllvm14-14.0.6     | 22.8 MB   | #######1                              |  19%
#
# qt-main-5.15.2       | 38.5 MB   | ####5                                 |  12%
#
#
#
#
#
#
#
#
# libllvm14-14.0.6     | 22.8 MB   | #######1                              |  19%
#
#
#
#
#
#
#
#
# libllvm14-14.0.6     | 22.8 MB   | #######2                              |  20%
#
# qt-main-5.15.2       | 38.5 MB   | ####6                                 |  12%
#
# qt-main-5.15.2       | 38.5 MB   | ####6                                 |  13%
#
#
#
#
#
#
#
#
# libllvm14-14.0.6     | 22.8 MB   | #######2                              |  20%
#
#
#
#
#
#
#
#
# libllvm14-14.0.6     | 22.8 MB   | #######3                              |  20%
#
# qt-main-5.15.2       | 38.5 MB   | ####6                                 |  13%
#
#
#
#
#
#
#
#
# libllvm14-14.0.6     | 22.8 MB   | #######3                              |  20%
#
# qt-main-5.15.2       | 38.5 MB   | ####7                                 |  13%
#
#
#
#
#
#
#
#
# libllvm14-14.0.6     | 22.8 MB   | #######4                              |  20%
#
# qt-main-5.15.2       | 38.5 MB   | ####7                                 |  13%
#
# qt-main-5.15.2       | 38.5 MB   | ####7                                 |  13%
#
#
#
#
#
#
#
#
# libllvm14-14.0.6     | 22.8 MB   | #######5                              |  20%
#
#
#
#
#
#
#
#
# libllvm14-14.0.6     | 22.8 MB   | #######5                              |  21%
#
# qt-main-5.15.2       | 38.5 MB   | ####7                                 |  13%
#
#
#
#
#
#
#
#
# libllvm14-14.0.6     | 22.8 MB   | #######6                              |  21%
#
# qt-main-5.15.2       | 38.5 MB   | ####8                                 |  13%
#
#
#
#
#
#
#
#
# libllvm14-14.0.6     | 22.8 MB   | #######7                              |  21%
#
# qt-main-5.15.2       | 38.5 MB   | ####8                                 |  13%
#
#
#
#
#
#
#
#
# libllvm14-14.0.6     | 22.8 MB   | #######8                              |  21%
#
# qt-main-5.15.2       | 38.5 MB   | ####8                                 |  13%
#
#
#
#
#
#
#
#
# libllvm14-14.0.6     | 22.8 MB   | #######9                              |  21%
#
# qt-main-5.15.2       | 38.5 MB   | ####9                                 |  13%
#
#
#
#
#
#
#
#
# libllvm14-14.0.6     | 22.8 MB   | #######9                              |  22%
#
# qt-main-5.15.2       | 38.5 MB   | ####9                                 |  13%
#
# qt-main-5.15.2       | 38.5 MB   | ####9                                 |  13%
#
#
#
#
#
#
#
#
# libllvm14-14.0.6     | 22.8 MB   | ########                              |  22%
#
# qt-main-5.15.2       | 38.5 MB   | #####                                 |  14%
#
#
#
#
#
#
#
#
# libllvm14-14.0.6     | 22.8 MB   | ########1                             |  22%
#
# qt-main-5.15.2       | 38.5 MB   | #####                                 |  14%
#
#
#
#
#
#
#
#
# libllvm14-14.0.6     | 22.8 MB   | ########2                             |  22%
#
# qt-main-5.15.2       | 38.5 MB   | #####                                 |  14%
#
#
#
#
#
#
#
#
# libllvm14-14.0.6     | 22.8 MB   | ########2                             |  22%
# qt-main-5.15.2       | 38.5 MB   | #####1                                |  14%
#
#
#
#
#
#
#
#
# libllvm14-14.0.6     | 22.8 MB   | ########3                             |  23%
#
# qt-main-5.15.2       | 38.5 MB   | #####1                                |  14%
#
#
#
#
#
#
#
#
# libllvm14-14.0.6     | 22.8 MB   | ########4                             |  23%
#
# qt-main-5.15.2       | 38.5 MB   | #####1                                |  14%
#
#
#
#
#
#
#
#
# libllvm14-14.0.6     | 22.8 MB   | ########4                             |  23%
#
# qt-main-5.15.2       | 38.5 MB   | #####2                                |  14%
#
#
#
#
#
#
#
#
# libllvm14-14.0.6     | 22.8 MB   | ########5                             |  23%
#
# qt-main-5.15.2       | 38.5 MB   | #####2                                |  14%
#
#
#
#
#
#
#
#
# libllvm14-14.0.6     | 22.8 MB   | ########6                             |  23%
#
# qt-main-5.15.2       | 38.5 MB   | #####2                                |  14%
#
#
#
#
#
#
#
#
# libllvm14-14.0.6     | 22.8 MB   | ########7                             |  24%
#
# qt-main-5.15.2       | 38.5 MB   | #####2                                |  14%
#
#
#
#
#
#
#
#
# libllvm14-14.0.6     | 22.8 MB   | ########7                             |  24%
#
# qt-main-5.15.2       | 38.5 MB   | #####3                                |  14%
#
#
#
#
#
#
#
#
# libllvm14-14.0.6     | 22.8 MB   | ########8                             |  24%
#
# qt-main-5.15.2       | 38.5 MB   | #####3                                |  15%
#
#
#
#
#
#
#
#
# libllvm14-14.0.6     | 22.8 MB   | ########9                             |  24%
#
# qt-main-5.15.2       | 38.5 MB   | #####3                                |  15%
#
# qt-main-5.15.2       | 38.5 MB   | #####4                                |  15%
#
#
#
#
#
#
#
#
# libllvm14-14.0.6     | 22.8 MB   | #########                             |  24%
#
# qt-main-5.15.2       | 38.5 MB   | #####4                                |  15%
#
#
#
#
#
#
#
#
# libllvm14-14.0.6     | 22.8 MB   | #########                             |  25%
#
# qt-main-5.15.2       | 38.5 MB   | #####4                                |  15%
#
#
#
#
#
#
#
#
# libllvm14-14.0.6     | 22.8 MB   | #########1                            |  25%
#
# qt-main-5.15.2       | 38.5 MB   | #####5                                |  15%
#
#
#
#
#
#
#
#
# libllvm14-14.0.6     | 22.8 MB   | #########2                            |  25%
#
# qt-main-5.15.2       | 38.5 MB   | #####5                                |  15%
#
# qt-main-5.15.2       | 38.5 MB   | #####5                                |  15%
#
#
#
#
#
#
#
#
# libllvm14-14.0.6     | 22.8 MB   | #########2                            |  25%
#
#
#
#
#
#
#
#
# libllvm14-14.0.6     | 22.8 MB   | #########3                            |  25%
#
# qt-main-5.15.2       | 38.5 MB   | #####6                                |  15%
#
# qt-main-5.15.2       | 38.5 MB   | #####6                                |  15%
#
#
#
#
#
#
#
#
# libllvm14-14.0.6     | 22.8 MB   | #########3                            |  25%
#
#
#
#
#
#
#
#
# libllvm14-14.0.6     | 22.8 MB   | #########4                            |  26%
#
# qt-main-5.15.2       | 38.5 MB   | #####6                                |  15%
#
# qt-main-5.15.2       | 38.5 MB   | #####7                                |  15%
#
#
#
#
#
#
#
#
# libllvm14-14.0.6     | 22.8 MB   | #########4                            |  26%
#
# qt-main-5.15.2       | 38.5 MB   | #####7                                |  16%
#
#
#
#
#
#
#
#
# libllvm14-14.0.6     | 22.8 MB   | #########5                            |  26%
#
# qt-main-5.15.2       | 38.5 MB   | #####7                                |  16%
#
#
#
#
#
#
#
#
# libllvm14-14.0.6     | 22.8 MB   | #########5                            |  26%
#
# qt-main-5.15.2       | 38.5 MB   | #####8                                |  16%
#
#
#
#
#
#
#
#
# libllvm14-14.0.6     | 22.8 MB   | #########6                            |  26%
#
# qt-main-5.15.2       | 38.5 MB   | #####8                                |  16%
#
#
#
#
#
#
#
#
# libllvm14-14.0.6     | 22.8 MB   | #########7                            |  26%
#
# qt-main-5.15.2       | 38.5 MB   | #####9                                |  16%
#
#
#
#
#
#
#
#
# libllvm14-14.0.6     | 22.8 MB   | #########8                            |  26%
#
# qt-main-5.15.2       | 38.5 MB   | #####9                                |  16%
#
# qt-main-5.15.2       | 38.5 MB   | #####9                                |  16%
#
#
#
#
#
#
#
#
# libllvm14-14.0.6     | 22.8 MB   | #########8                            |  27%
#
#
#
#
#
#
#
#
# libllvm14-14.0.6     | 22.8 MB   | #########9                            |  27%
#
# qt-main-5.15.2       | 38.5 MB   | ######                                |  16%
#
#
#
#
#
#
#
#
# libllvm14-14.0.6     | 22.8 MB   | #########9                            |  27%
#
# qt-main-5.15.2       | 38.5 MB   | ######                                |  16%
#
#
#
#
#
#
#
#
# libllvm14-14.0.6     | 22.8 MB   | ##########                            |  27%
#
# qt-main-5.15.2       | 38.5 MB   | ######1                               |  17%
#
#
#
#
#
#
#
#
# libllvm14-14.0.6     | 22.8 MB   | ##########                            |  27%
#
# qt-main-5.15.2       | 38.5 MB   | ######1                               |  17%
#
#
#
#
#
#
#
#
# libllvm14-14.0.6     | 22.8 MB   | ##########1                           |  27%
#
# qt-main-5.15.2       | 38.5 MB   | ######2                               |  17%
#
#
#
#
#
#
#
#
# libllvm14-14.0.6     | 22.8 MB   | ##########1                           |  28%
#
# qt-main-5.15.2       | 38.5 MB   | ######2                               |  17%
#
#
#
#
#
#
#
#
# libllvm14-14.0.6     | 22.8 MB   | ##########2                           |  28%
#
# qt-main-5.15.2       | 38.5 MB   | ######2                               |  17%
#
#
#
#
#
#
#
#
# libllvm14-14.0.6     | 22.8 MB   | ##########2                           |  28%
#
# qt-main-5.15.2       | 38.5 MB   | ######3                               |  17%
#
#
#
#
#
#
#
#
# libllvm14-14.0.6     | 22.8 MB   | ##########3                           |  28%
#
# qt-main-5.15.2       | 38.5 MB   | ######3                               |  17%
#
#
#
#
#
#
#
#
# libllvm14-14.0.6     | 22.8 MB   | ##########3                           |  28%
#
# qt-main-5.15.2       | 38.5 MB   | ######4                               |  17%
#
#
#
#
#
#
#
#
# libllvm14-14.0.6     | 22.8 MB   | ##########4                           |  28%
#
# qt-main-5.15.2       | 38.5 MB   | ######4                               |  18%
#
#
#
#
#
#
#
#
# libllvm14-14.0.6     | 22.8 MB   | ##########4                           |  28%
#
#
#
#
#
#
#
#
# libllvm14-14.0.6     | 22.8 MB   | ##########5                           |  28%
#
# qt-main-5.15.2       | 38.5 MB   | ######5                               |  18%
#
#
#
#
#
#
#
#
# libllvm14-14.0.6     | 22.8 MB   | ##########5                           |  29%
#
# qt-main-5.15.2       | 38.5 MB   | ######5                               |  18%
#
# qt-main-5.15.2       | 38.5 MB   | ######6                               |  18%
#
#
#
#
#
#
#
#
# libllvm14-14.0.6     | 22.8 MB   | ##########6                           |  29%
# qt-main-5.15.2       | 38.5 MB   | ######6                               |  18%
#
#
#
#
#
#
#
#
# libllvm14-14.0.6     | 22.8 MB   | ##########7                           |  29%
#
# qt-main-5.15.2       | 38.5 MB   | ######7                               |  18%
#
#
#
#
#
#
#
#
# libllvm14-14.0.6     | 22.8 MB   | ##########7                           |  29%
#
# qt-main-5.15.2       | 38.5 MB   | ######7                               |  18%
#
#
#
#
#
#
#
#
# libllvm14-14.0.6     | 22.8 MB   | ##########8                           |  29%
#
#
#
#
#
#
#
#
# libllvm14-14.0.6     | 22.8 MB   | ##########8                           |  29%
#
# qt-main-5.15.2       | 38.5 MB   | ######7                               |  18%
#
# qt-main-5.15.2       | 38.5 MB   | ######8                               |  18%
#
#
#
#
#
#
#
#
# libllvm14-14.0.6     | 22.8 MB   | ##########9                           |  30%
#
# qt-main-5.15.2       | 38.5 MB   | ######8                               |  19%
#
#
#
#
#
#
#
#
# libllvm14-14.0.6     | 22.8 MB   | ##########9                           |  30%
#
# qt-main-5.15.2       | 38.5 MB   | ######9                               |  19%
#
#
#
#
#
#
#
#
# libllvm14-14.0.6     | 22.8 MB   | ###########                           |  30%
#
# qt-main-5.15.2       | 38.5 MB   | ######9                               |  19%
#
#
#
#
#
#
#
#
# libllvm14-14.0.6     | 22.8 MB   | ###########                           |  30%
#
# qt-main-5.15.2       | 38.5 MB   | #######                               |  19%
#
# qt-main-5.15.2       | 38.5 MB   | #######                               |  19%
#
#
#
#
#
#
#
#
# libllvm14-14.0.6     | 22.8 MB   | ###########1                          |  30%
#
# qt-main-5.15.2       | 38.5 MB   | #######1                              |  19%
#
#
#
#
#
#
#
#
# libllvm14-14.0.6     | 22.8 MB   | ###########1                          |  30%
#
# qt-main-5.15.2       | 38.5 MB   | #######1                              |  19%
#
#
#
#
#
#
#
#
# libllvm14-14.0.6     | 22.8 MB   | ###########2                          |  30%
#
# qt-main-5.15.2       | 38.5 MB   | #######1                              |  19%
#
#
#
#
#
#
#
#
# libllvm14-14.0.6     | 22.8 MB   | ###########2                          |  30%
#
# qt-main-5.15.2       | 38.5 MB   | #######2                              |  20%
#
#
#
#
#
#
#
#
# libllvm14-14.0.6     | 22.8 MB   | ###########3                          |  31%
#
# qt-main-5.15.2       | 38.5 MB   | #######2                              |  20%
#
#
#
#
#
#
#
#
# libllvm14-14.0.6     | 22.8 MB   | ###########3                          |  31%
#
# qt-main-5.15.2       | 38.5 MB   | #######3                              |  20%
#
#
#
#
#
#
#
#
# libllvm14-14.0.6     | 22.8 MB   | ###########4                          |  31%
#
# qt-main-5.15.2       | 38.5 MB   | #######3                              |  20%
#
#
#
#
#
#
#
#
# libllvm14-14.0.6     | 22.8 MB   | ###########4                          |  31%
#
# qt-main-5.15.2       | 38.5 MB   | #######4                              |  20%
#
#
#
#
#
#
#
#
# libllvm14-14.0.6     | 22.8 MB   | ###########5                          |  31%
#
# qt-main-5.15.2       | 38.5 MB   | #######4                              |  20%
#
#
#
#
#
#
#
#
# libllvm14-14.0.6     | 22.8 MB   | ###########5                          |  31%
#
#
#
#
#
#
#
#
# libllvm14-14.0.6     | 22.8 MB   | ###########6                          |  31%
#
# ...
#
# qt-main-5.15.2       | 38.5 MB   | ##############################7       |  83%
#
# qt-main-5.15.2       | 38.5 MB   | ##############################7       |  83%
#
# qt-main-5.15.2       | 38.5 MB   | ##############################7       |  83%
#
# qt-main-5.15.2       | 38.5 MB   | ##############################8       |  83%
#
# qt-main-5.15.2       | 38.5 MB   | ##############################8       |  83%
#
# qt-main-5.15.2       | 38.5 MB   | ##############################9       |  84%
#
# qt-main-5.15.2       | 38.5 MB   | ##############################9       |  84%
#
# qt-main-5.15.2       | 38.5 MB   | ##############################9       |  84%
#
# qt-main-5.15.2       | 38.5 MB   | ###############################       |  84%
#
# qt-main-5.15.2       | 38.5 MB   | ###############################       |  84%
#
# qt-main-5.15.2       | 38.5 MB   | ###############################       |  84%
#
# qt-main-5.15.2       | 38.5 MB   | ###############################       |  84%
#
# qt-main-5.15.2       | 38.5 MB   | ###############################1      |  84%
# qt-main-5.15.2       | 38.5 MB   | ###############################1      |  84%
#
# qt-main-5.15.2       | 38.5 MB   | ###############################2      |  84%
#
# qt-main-5.15.2       | 38.5 MB   | ###############################2      |  84%
#
# qt-main-5.15.2       | 38.5 MB   | ###############################2      |  85%
#
# qt-main-5.15.2       | 38.5 MB   | ###############################3      |  85%
#
# qt-main-5.15.2       | 38.5 MB   | ###############################3      |  85%
#
# qt-main-5.15.2       | 38.5 MB   | ###############################3      |  85%
#
# qt-main-5.15.2       | 38.5 MB   | ###############################4      |  85%
#
# qt-main-5.15.2       | 38.5 MB   | ###############################4      |  85%
#
# qt-main-5.15.2       | 38.5 MB   | ###############################4      |  85%
#
# qt-main-5.15.2       | 38.5 MB   | ###############################5      |  85%
#
# qt-main-5.15.2       | 38.5 MB   | ###############################5      |  85%
#
# qt-main-5.15.2       | 38.5 MB   | ###############################6      |  85%
#
# qt-main-5.15.2       | 38.5 MB   | ###############################6      |  86%
#
# qt-main-5.15.2       | 38.5 MB   | ###############################6      |  86%
#
# qt-main-5.15.2       | 38.5 MB   | ###############################7      |  86%
#
# qt-main-5.15.2       | 38.5 MB   | ###############################7      |  86%
#
# qt-main-5.15.2       | 38.5 MB   | ###############################8      |  86%
#
# qt-main-5.15.2       | 38.5 MB   | ###############################8      |  86%
#
# qt-main-5.15.2       | 38.5 MB   | ###############################8      |  86%
#
# qt-main-5.15.2       | 38.5 MB   | ###############################9      |  86%
#
# qt-main-5.15.2       | 38.5 MB   | ###############################9      |  86%
#
# qt-main-5.15.2       | 38.5 MB   | ################################      |  87%
#
# qt-main-5.15.2       | 38.5 MB   | ################################      |  87%
#
# qt-main-5.15.2       | 38.5 MB   | ################################      |  87%
#
# qt-main-5.15.2       | 38.5 MB   | ################################1     |  87%
#
# qt-main-5.15.2       | 38.5 MB   | ################################1     |  87%
#
# qt-main-5.15.2       | 38.5 MB   | ################################1     |  87%
#
# qt-main-5.15.2       | 38.5 MB   | ################################2     |  87%
#
# qt-main-5.15.2       | 38.5 MB   | ################################2     |  87%
#
# qt-main-5.15.2       | 38.5 MB   | ################################2     |  87%
#
# qt-main-5.15.2       | 38.5 MB   | ################################3     |  87%
#
# qt-main-5.15.2       | 38.5 MB   | ################################3     |  87%
#
# qt-main-5.15.2       | 38.5 MB   | ################################4     |  88%
#
# qt-main-5.15.2       | 38.5 MB   | ################################4     |  88%
#
# qt-main-5.15.2       | 38.5 MB   | ################################5     |  88%
#
# qt-main-5.15.2       | 38.5 MB   | ################################5     |  88%
#
# qt-main-5.15.2       | 38.5 MB   | ################################5     |  88%
#
# qt-main-5.15.2       | 38.5 MB   | ################################6     |  88%
#
# qt-main-5.15.2       | 38.5 MB   | ################################6     |  88%
#
# qt-main-5.15.2       | 38.5 MB   | ################################6     |  88%
#
# qt-main-5.15.2       | 38.5 MB   | ################################7     |  88%
#
# qt-main-5.15.2       | 38.5 MB   | ################################7     |  88%
#
# qt-main-5.15.2       | 38.5 MB   | ################################7     |  89%
#
# qt-main-5.15.2       | 38.5 MB   | ################################7     |  89%
#
# qt-main-5.15.2       | 38.5 MB   | ################################8     |  89%
#
# qt-main-5.15.2       | 38.5 MB   | ################################8     |  89%
#
# qt-main-5.15.2       | 38.5 MB   | ################################8     |  89%
#
# qt-main-5.15.2       | 38.5 MB   | ################################9     |  89%
#
# qt-main-5.15.2       | 38.5 MB   | ################################9     |  89%
#
# qt-main-5.15.2       | 38.5 MB   | ################################9     |  89%
#
# qt-main-5.15.2       | 38.5 MB   | #################################     |  89%
#
# qt-main-5.15.2       | 38.5 MB   | #################################     |  89%
#
# qt-main-5.15.2       | 38.5 MB   | #################################     |  89%
#
# qt-main-5.15.2       | 38.5 MB   | #################################     |  89%
#
# qt-main-5.15.2       | 38.5 MB   | #################################1    |  90%
#
# qt-main-5.15.2       | 38.5 MB   | #################################1    |  90%
#
# qt-main-5.15.2       | 38.5 MB   | #################################1    |  90%
#
# qt-main-5.15.2       | 38.5 MB   | #################################2    |  90%
#
# qt-main-5.15.2       | 38.5 MB   | #################################2    |  90%
#
# qt-main-5.15.2       | 38.5 MB   | #################################2    |  90%
#
# qt-main-5.15.2       | 38.5 MB   | #################################3    |  90%
#
# qt-main-5.15.2       | 38.5 MB   | #################################3    |  90%
#
# qt-main-5.15.2       | 38.5 MB   | #################################3    |  90%
#
# qt-main-5.15.2       | 38.5 MB   | #################################4    |  90%
#
# qt-main-5.15.2       | 38.5 MB   | #################################4    |  90%
#
# qt-main-5.15.2       | 38.5 MB   | #################################4    |  90%
#
# qt-main-5.15.2       | 38.5 MB   | #################################5    |  91%
#
# qt-main-5.15.2       | 38.5 MB   | #################################5    |  91%
#
# qt-main-5.15.2       | 38.5 MB   | #################################5    |  91%
#
# qt-main-5.15.2       | 38.5 MB   | #################################6    |  91%
#
# qt-main-5.15.2       | 38.5 MB   | #################################6    |  91%
#
# qt-main-5.15.2       | 38.5 MB   | #################################6    |  91%
#
# qt-main-5.15.2       | 38.5 MB   | #################################7    |  91%
#
# qt-main-5.15.2       | 38.5 MB   | #################################7    |  91%
#
# qt-main-5.15.2       | 38.5 MB   | #################################7    |  91%
#
# qt-main-5.15.2       | 38.5 MB   | #################################8    |  91%
#
# qt-main-5.15.2       | 38.5 MB   | #################################8    |  91%
#
# qt-main-5.15.2       | 38.5 MB   | #################################8    |  92%
#
# qt-main-5.15.2       | 38.5 MB   | #################################9    |  92%
#
# qt-main-5.15.2       | 38.5 MB   | #################################9    |  92%
#
# qt-main-5.15.2       | 38.5 MB   | #################################9    |  92%
#
# qt-main-5.15.2       | 38.5 MB   | #################################9    |  92%
#
# qt-main-5.15.2       | 38.5 MB   | ##################################    |  92%
#
# qt-main-5.15.2       | 38.5 MB   | ##################################    |  92%
#
# qt-main-5.15.2       | 38.5 MB   | ##################################    |  92%
#
# qt-main-5.15.2       | 38.5 MB   | ##################################1   |  92%
#
# qt-main-5.15.2       | 38.5 MB   | ##################################1   |  92%
#
# qt-main-5.15.2       | 38.5 MB   | ##################################1   |  92%
#
# qt-main-5.15.2       | 38.5 MB   | ##################################2   |  92%
#
# qt-main-5.15.2       | 38.5 MB   | ##################################2   |  93%
#
# qt-main-5.15.2       | 38.5 MB   | ##################################2   |  93%
#
# qt-main-5.15.2       | 38.5 MB   | ##################################3   |  93%
# qt-main-5.15.2       | 38.5 MB   | ##################################3   |  93%
#
# qt-main-5.15.2       | 38.5 MB   | ##################################3   |  93%
#
# qt-main-5.15.2       | 38.5 MB   | ##################################4   |  93%
#
# qt-main-5.15.2       | 38.5 MB   | ##################################4   |  93%
#
# qt-main-5.15.2       | 38.5 MB   | ##################################4   |  93%
#
# qt-main-5.15.2       | 38.5 MB   | ##################################4   |  93%
#
# qt-main-5.15.2       | 38.5 MB   | ##################################5   |  93%
#
# qt-main-5.15.2       | 38.5 MB   | ##################################5   |  93%
#
# qt-main-5.15.2       | 38.5 MB   | ##################################5   |  94%
#
# qt-main-5.15.2       | 38.5 MB   | ##################################6   |  94%
#
# qt-main-5.15.2       | 38.5 MB   | ##################################6   |  94%
#
# qt-main-5.15.2       | 38.5 MB   | ##################################6   |  94%
#
# qt-main-5.15.2       | 38.5 MB   | ##################################7   |  94%
#
# qt-main-5.15.2       | 38.5 MB   | ##################################7   |  94%
#
# qt-main-5.15.2       | 38.5 MB   | ##################################7   |  94%
#
# qt-main-5.15.2       | 38.5 MB   | ##################################8   |  94%
#
# qt-main-5.15.2       | 38.5 MB   | ##################################8   |  94%
#
# qt-main-5.15.2       | 38.5 MB   | ##################################8   |  94%
#
# qt-main-5.15.2       | 38.5 MB   | ##################################8   |  94%
#
# qt-main-5.15.2       | 38.5 MB   | ##################################9   |  94%
#
# qt-main-5.15.2       | 38.5 MB   | ##################################9   |  95%
#
# qt-main-5.15.2       | 38.5 MB   | ###################################   |  95%
#
# qt-main-5.15.2       | 38.5 MB   | ###################################   |  95%
#
# qt-main-5.15.2       | 38.5 MB   | ###################################   |  95%
#
# qt-main-5.15.2       | 38.5 MB   | ###################################   |  95%
#
# qt-main-5.15.2       | 38.5 MB   | ###################################1  |  95%
#
# qt-main-5.15.2       | 38.5 MB   | ###################################1  |  95%
#
# qt-main-5.15.2       | 38.5 MB   | ###################################1  |  95%
#
# qt-main-5.15.2       | 38.5 MB   | ###################################2  |  95%
#
# qt-main-5.15.2       | 38.5 MB   | ###################################2  |  95%
#
# qt-main-5.15.2       | 38.5 MB   | ###################################2  |  95%
#
# qt-main-5.15.2       | 38.5 MB   | ###################################3  |  95%
#
# qt-main-5.15.2       | 38.5 MB   | ###################################3  |  95%
#
# qt-main-5.15.2       | 38.5 MB   | ###################################3  |  96%
#
# qt-main-5.15.2       | 38.5 MB   | ###################################3  |  96%
#
# qt-main-5.15.2       | 38.5 MB   | ###################################4  |  96%
#
# qt-main-5.15.2       | 38.5 MB   | ###################################4  |  96%
#
# qt-main-5.15.2       | 38.5 MB   | ###################################4  |  96%
#
# qt-main-5.15.2       | 38.5 MB   | ###################################5  |  96%
#
# qt-main-5.15.2       | 38.5 MB   | ###################################5  |  96%
#
# qt-main-5.15.2       | 38.5 MB   | ###################################5  |  96%
#
# qt-main-5.15.2       | 38.5 MB   | ###################################6  |  96%
#
# qt-main-5.15.2       | 38.5 MB   | ###################################6  |  96%
#
# qt-main-5.15.2       | 38.5 MB   | ###################################6  |  96%
#
# qt-main-5.15.2       | 38.5 MB   | ###################################7  |  97%
#
# qt-main-5.15.2       | 38.5 MB   | ###################################7  |  97%
#
# qt-main-5.15.2       | 38.5 MB   | ###################################7  |  97%
#
# qt-main-5.15.2       | 38.5 MB   | ###################################8  |  97%
#
# qt-main-5.15.2       | 38.5 MB   | ###################################8  |  97%
#
# qt-main-5.15.2       | 38.5 MB   | ###################################8  |  97%
#
# qt-main-5.15.2       | 38.5 MB   | ###################################8  |  97%
#
# qt-main-5.15.2       | 38.5 MB   | ###################################9  |  97%
#
# qt-main-5.15.2       | 38.5 MB   | ###################################9  |  97%
#
# qt-main-5.15.2       | 38.5 MB   | ###################################9  |  97%
#
# qt-main-5.15.2       | 38.5 MB   | ####################################  |  97%
#
# qt-main-5.15.2       | 38.5 MB   | ####################################  |  97%
#
# qt-main-5.15.2       | 38.5 MB   | ####################################  |  97%
#
# qt-main-5.15.2       | 38.5 MB   | ####################################1 |  98%
#
# qt-main-5.15.2       | 38.5 MB   | ####################################1 |  98%
#
# qt-main-5.15.2       | 38.5 MB   | ####################################1 |  98%
#
# qt-main-5.15.2       | 38.5 MB   | ####################################1 |  98%
#
# qt-main-5.15.2       | 38.5 MB   | ####################################2 |  98%
#
# qt-main-5.15.2       | 38.5 MB   | ####################################2 |  98%
#
# qt-main-5.15.2       | 38.5 MB   | ####################################2 |  98%
#
# qt-main-5.15.2       | 38.5 MB   | ####################################3 |  98%
#
# qt-main-5.15.2       | 38.5 MB   | ####################################3 |  98%
#
# qt-main-5.15.2       | 38.5 MB   | ####################################3 |  98%
#
# qt-main-5.15.2       | 38.5 MB   | ####################################4 |  98%
#
# qt-main-5.15.2       | 38.5 MB   | ####################################4 |  98%
#
# qt-main-5.15.2       | 38.5 MB   | ####################################4 |  99%
#
# qt-main-5.15.2       | 38.5 MB   | ####################################4 |  99%
#
# qt-main-5.15.2       | 38.5 MB   | ####################################5 |  99%
#
# qt-main-5.15.2       | 38.5 MB   | ####################################5 |  99%
#
# qt-main-5.15.2       | 38.5 MB   | ####################################5 |  99%
#
# qt-main-5.15.2       | 38.5 MB   | ####################################6 |  99%
#
# qt-main-5.15.2       | 38.5 MB   | ####################################6 |  99%
#
# qt-main-5.15.2       | 38.5 MB   | ####################################6 |  99%
#
# qt-main-5.15.2       | 38.5 MB   | ####################################7 |  99%
#
# qt-main-5.15.2       | 38.5 MB   | ####################################7 |  99%
#
# qt-main-5.15.2       | 38.5 MB   | ####################################7 |  99%
#
# qt-main-5.15.2       | 38.5 MB   | ####################################7 |  99%
#
# qt-main-5.15.2       | 38.5 MB   | ####################################8 | 100%
#
# qt-main-5.15.2       | 38.5 MB   | ####################################8 | 100%
#
# qt-main-5.15.2       | 38.5 MB   | ####################################8 | 100%
#
# qt-main-5.15.2       | 38.5 MB   | ####################################9 | 100%
#
# qt-main-5.15.2       | 38.5 MB   | ####################################9 | 100%
#
# qt-main-5.15.2       | 38.5 MB   | ####################################9 | 100%
#
# qt-main-5.15.2       | 38.5 MB   | ##################################### | 100%
#
# qt-main-5.15.2       | 38.5 MB   | ##################################### | 100%
